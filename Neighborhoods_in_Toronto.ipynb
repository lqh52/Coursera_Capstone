# %% [markdown]
# <a href="https://colab.research.google.com/github/lqh52/Coursera_Capstone/blob/main/Neighborhoods_in_Toronto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import necessary library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %% [markdown]
# ## Import data

# %%
table= pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# %%
table[0]
# Out:
#     Postal Code  ...                                      Neighbourhood
# 0           M1A  ...                                       Not assigned
# 1           M2A  ...                                       Not assigned
# 2           M3A  ...                                          Parkwoods
# 3           M4A  ...                                   Victoria Village
# 4           M5A  ...                          Regent Park, Harbourfront
# ..          ...  ...                                                ...
# 175         M5Z  ...                                       Not assigned
# 176         M6Z  ...                                       Not assigned
# 177         M7Z  ...                                       Not assigned
# 178         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
# 179         M9Z  ...                                       Not assigned
#
# [180 rows x 3 columns]

# %%
df = table[0]
df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# Remove empty data

# %%
df.drop(df[df.Borough == 'Not assigned'].index, inplace=True)

# %%
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# Prepare data

# %%
df.groupby('Postal Code')['Neighbourhood'].apply(','.join)
# Out:
# Postal Code
# M1B                                       Malvern, Rouge
# M1C               Rouge Hill, Port Union, Highland Creek
# M1E                    Guildwood, Morningside, West Hill
# M1G                                               Woburn
# M1H                                            Cedarbrae
#                              ...
# M9N                                               Weston
# M9P                                            Westmount
# M9R    Kingsview Village, St. Phillips, Martin Grove ...
# M9V    South Steeles, Silverstone, Humbergate, Jamest...
# M9W                  Northwest, West Humber - Clairville
# Name: Neighbourhood, Length: 103, dtype: object

# %%
df.shape
# Out:
# (103, 3)

# %%
geo = pd.read_csv('/content/Geospatial_Coordinates.csv')

# %%
geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
pd.merge(df,geo,on='Postal Code')
# Out:
#     Postal Code           Borough  ...   Latitude  Longitude
# 0           M3A        North York  ...  43.753259 -79.329656
# 1           M4A        North York  ...  43.725882 -79.315572
# 2           M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3           M6A        North York  ...  43.718518 -79.464763
# 4           M7A  Downtown Toronto  ...  43.662301 -79.389494
# ..          ...               ...  ...        ...        ...
# 98          M8X         Etobicoke  ...  43.653654 -79.506944
# 99          M4Y  Downtown Toronto  ...  43.665860 -79.383160
# 100         M7Y      East Toronto  ...  43.662744 -79.321558
# 101         M8Y         Etobicoke  ...  43.636258 -79.498509
# 102         M8Z         Etobicoke  ...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
df
# Out:
#     Postal Code  ...                                      Neighbourhood
# 2           M3A  ...                                          Parkwoods
# 3           M4A  ...                                   Victoria Village
# 4           M5A  ...                          Regent Park, Harbourfront
# 5           M6A  ...                   Lawrence Manor, Lawrence Heights
# 6           M7A  ...        Queen's Park, Ontario Provincial Government
# ..          ...  ...                                                ...
# 160         M8X  ...      The Kingsway, Montgomery Road, Old Mill North
# 165         M4Y  ...                               Church and Wellesley
# 168         M7Y  ...  Business reply mail Processing Centre, South C...
# 169         M8Y  ...  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
neighborhoods = pd.merge(df,geo,on='Postal Code')

# %% [markdown]
# ## Implement k-means

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans
import folium # map rendering library

# %%
# !pip install geopy

# %%
from geopy.geocoders import Nominatim

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="trt_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# Toronto's map

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
neighborhoods
# Out:
#     Postal Code           Borough  ...   Latitude  Longitude
# 0           M3A        North York  ...  43.753259 -79.329656
# 1           M4A        North York  ...  43.725882 -79.315572
# 2           M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3           M6A        North York  ...  43.718518 -79.464763
# 4           M7A  Downtown Toronto  ...  43.662301 -79.389494
# ..          ...               ...  ...        ...        ...
# 98          M8X         Etobicoke  ...  43.653654 -79.506944
# 99          M4Y  Downtown Toronto  ...  43.665860 -79.383160
# 100         M7Y      East Toronto  ...  43.662744 -79.321558
# 101         M8Y         Etobicoke  ...  43.636258 -79.498509
# 102         M8Z         Etobicoke  ...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
toronto_grouped = neighborhoods.groupby('Neighbourhood').mean().reset_index()

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 2, 0, 0, 0, 3, 1, 3, 1, 3], dtype=int32)

# %%
# add clustering labels
toronto_grouped.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_grouped
# Out:
#     Cluster Labels  ...  Longitude
# 0                4  ... -79.262029
# 1                2  ... -79.543484
# 2                0  ... -79.442259
# 3                0  ... -79.385975
# 4                0  ... -79.419750
# ..             ...  ...        ...
# 94               0  ... -79.442259
# 95               4  ... -79.216917
# 96               1  ... -79.318389
# 97               0  ... -79.400049
# 98               0  ... -79.374714
#
# [99 rows x 4 columns]

# %%
neighborhoods = pd.merge(neighborhoods, toronto_grouped, on = ['Neighbourhood'])
neighborhoods
# Out:
#     Postal Code           Borough  ... Latitude_y  Longitude_y
# 0           M3A        North York  ...  43.753259   -79.329656
# 1           M4A        North York  ...  43.725882   -79.315572
# 2           M5A  Downtown Toronto  ...  43.654260   -79.360636
# 3           M6A        North York  ...  43.718518   -79.464763
# 4           M7A  Downtown Toronto  ...  43.662301   -79.389494
# ..          ...               ...  ...        ...          ...
# 98          M8X         Etobicoke  ...  43.653654   -79.506944
# 99          M4Y  Downtown Toronto  ...  43.665860   -79.383160
# 100         M7Y      East Toronto  ...  43.662744   -79.321558
# 101         M8Y         Etobicoke  ...  43.636258   -79.498509
# 102         M8Z         Etobicoke  ...  43.628841   -79.520999
#
# [103 rows x 8 columns]

# %%
neighborhoods.drop(['Latitude_y', 'Longitude_y'], 1)
# Out:
#     Postal Code           Borough  ... Longitude_x  Cluster Labels
# 0           M3A        North York  ...  -79.329656               1
# 1           M4A        North York  ...  -79.315572               1
# 2           M5A  Downtown Toronto  ...  -79.360636               3
# 3           M6A        North York  ...  -79.464763               0
# 4           M7A  Downtown Toronto  ...  -79.389494               3
# ..          ...               ...  ...         ...             ...
# 98          M8X         Etobicoke  ...  -79.506944               2
# 99          M4Y  Downtown Toronto  ...  -79.383160               3
# 100         M7Y      East Toronto  ...  -79.321558               1
# 101         M8Y         Etobicoke  ...  -79.498509               2
# 102         M8Z         Etobicoke  ...  -79.520999               2
#
# [103 rows x 6 columns]

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# Toronto's map after clustering

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(neighborhoods['Latitude_x'], neighborhoods['Longitude_x'], neighborhoods['Neighbourhood'], neighborhoods['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
